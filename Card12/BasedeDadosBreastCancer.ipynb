# %% [markdown]
# ## Base de dados: https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic
#
# ## Informações do conjunto de dados
# As características são calculadas a partir de uma imagem digitalizada de um aspirado com agulha fina (PAAF) de uma massa mamária. Eles descrevem características dos núcleos celulares presentes na imagem. Algumas das imagens podem ser encontradas em http://www.cs.wisc.edu/~street/images/
#
# O plano de separação descrito acima foi obtido usando Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Construção de árvore de decisão por meio de programação linear". Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], um método de classificação que usa programação linear para construir uma árvore de decisão. As características relevantes foram selecionadas usando uma pesquisa exaustiva no espaço de 1-4 características e 1-3 planos de separação.
#
# O programa linear real usado para obter o plano de separação no espaço tridimensional é aquele descrito em: [K. P. Bennett e OL Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].
#
#  Este banco de dados também está disponível através do servidor FTP UW CS:
#  ftp ftp.cs.wisc.edu
#  cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# Tem valores ausentes?
# Não

# %%
import pandas as pd

# %%
x = pd.read_csv('entradas_breast.csv')

# %%
x
# Out:
#       radius_mean   texture_mean   perimeter_mean   area_mean  \
# 0           17.99          10.38           122.80      1001.0
# 1           20.57          17.77           132.90      1326.0
# 2           19.69          21.25           130.00      1203.0
# 3           11.42          20.38            77.58       386.1
# 4           20.29          14.34           135.10      1297.0
# ..            ...            ...              ...         ...
# 564         21.56          22.39           142.00      1479.0
# 565         20.13          28.25           131.20      1261.0
# 566         16.60          28.08           108.30       858.1
# 567         20.60          29.33           140.10      1265.0
# 568          7.76          24.54            47.92       181.0
#
#       smoothness_mean   compactness_mean   concavity_mean  \
# 0             0.11840            0.27760          0.30010
# 1             0.08474            0.07864          0.08690
# ...

# %%
y = pd.read_csv('saidas_breast.csv')

# %%
y
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 564  0
# 565  0
# 566  0
# 567  0
# 568  1
#
# [569 rows x 1 columns]

# %%
import sklearn 
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential

# %%
(30 + 1)/2
# Out:
# 15.5

# %%
rede_neural = Sequential([
    tf.keras.layers.InputLayer(shape=(30,)),
    tf.keras.layers.Dense(units=16, activation='relu', kernel_initializer='random_uniform'),
    tf.keras.layers.Dense(units=1, activation='sigmoid'),
])

# %%
rede_neural.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 513 (2.00 KB)
#  Trainable params: 513 (2.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
rede_neural.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy'])

# %%
rede_neural.fit(x_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - binary_accuracy: 0.5697 - loss: 42.0288
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - binary_accuracy: 0.6991 - loss: 1.6248
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.7529 - loss: 1.2288
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - binary_accuracy: 0.7798 - loss: 0.9650
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - binary_accuracy: 0.8170 - loss: 0.6911
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - binary_accuracy: 0.8256 - loss: 0.6222
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - binary_accuracy: 0.8745 - loss: 0.4744
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - binary_accuracy: 0.8684 - loss: 0.4752
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - binary_accuracy: 0.8575 - loss: 0.5553
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - binary_accuracy: 0.9136 - loss: 0.3496
# Epoch 11/100
# ...

# %%
rede_neural.fit(x_train, y_train, batch_size=10, epochs=500)
# Out:
# Epoch 1/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - binary_accuracy: 0.9107 - loss: 0.3662
# Epoch 2/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - binary_accuracy: 0.9150 - loss: 0.2909
# Epoch 3/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - binary_accuracy: 0.8493 - loss: 1.1652
# Epoch 4/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9006 - loss: 0.5763
# Epoch 5/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9346 - loss: 0.2217
# Epoch 6/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9393 - loss: 0.2508
# Epoch 7/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9200 - loss: 0.4070
# Epoch 8/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9207 - loss: 0.3568
# Epoch 9/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9282 - loss: 0.4305
# Epoch 10/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9220 - loss: 0.3470
# Epoch 11/500
# ...

# %%
rede_neural.fit(x_train, y_train, batch_size=10, epochs=250)
# Out:
# Epoch 1/250
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9829 - loss: 0.0535
# Epoch 2/250
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - binary_accuracy: 0.9709 - loss: 0.0754
# Epoch 3/250
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - binary_accuracy: 0.9436 - loss: 0.1533
# Epoch 4/250
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - binary_accuracy: 0.9761 - loss: 0.0685
# Epoch 5/250
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9577 - loss: 0.1202
# Epoch 6/250
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - binary_accuracy: 0.9651 - loss: 0.0997
# Epoch 7/250
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - binary_accuracy: 0.9567 - loss: 0.0851
# Epoch 8/250
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - binary_accuracy: 0.9565 - loss: 0.0975
# Epoch 9/250
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - binary_accuracy: 0.9588 - loss: 0.0858
# Epoch 10/250
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9685 - loss: 0.0793
# Epoch 11/250
# ...

# %%
x_test
# Out:
#       radius_mean   texture_mean   perimeter_mean   area_mean  \
# 512         13.40          20.52            88.64       556.7
# 457         13.21          25.25            84.10       537.9
# 439         14.02          15.66            89.59       606.5
# 298         14.26          18.17            91.22       633.1
# 37          13.03          18.42            82.61       523.8
# ..            ...            ...              ...         ...
# 236         23.21          26.97           153.50      1670.0
# 113         10.51          20.19            68.64       334.2
# 527         12.34          12.27            78.94       468.5
# 76          13.53          10.94            87.91       559.2
# 162         19.59          18.15           130.70      1214.0
#
#       smoothness_mean   compactness_mean   concavity_mean  \
# 512           0.11060            0.14690          0.14450
# 457           0.08791            0.05205          0.02772
# ...

# %%
previsoes = rede_neural.predict(x_test)
previsoes  = (previsoes) > 0.5
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
previsoes
# Out:
# array([[False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
# ...

# %%
y_test
# Out:
#      0
# 512  0
# 457  1
# 439  1
# 298  1
# 37   1
# ..  ..
# 236  0
# 113  1
# 527  1
# 76   1
# 162  0
#
# [143 rows x 1 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
accuracy = accuracy_score(y_test, previsoes)
accuracy
# Out:
# 0.9090909090909091

# %%
confusion_matrix(y_test, previsoes)
# Out:
# array([[49,  4],
#        [ 9, 81]], dtype=int64)

# %%
49+82 , 3+8
# Out:
# (131, 11)

# %%
132/143 , 11/143
# Out:
# (0.9230769230769231, 0.07692307692307693)

# %%
rede_neural.evaluate(x_test, y_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.8911 - loss: 0.7981
# [0.7754320502281189, 0.9090909361839294]

# %%
rede_neural = Sequential([
    tf.keras.layers.InputLayer(shape=(30,)),
    tf.keras.layers.Dense(units=16, activation='relu', kernel_initializer='random_uniform'),
     tf.keras.layers.Dense(units=16, activation='relu', kernel_initializer='random_uniform'),
    tf.keras.layers.Dense(units=1, activation='sigmoid'),
])

# %%
rede_neural.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 785 (3.07 KB)
#  Trainable params: 785 (3.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
otimizador =tf.keras.optimizers.Adam(learning_rate=0.0001, clipvalue=0.5)

# %%
rede_neural.compile(optimizer=otimizador, loss='binary_crossentropy', metrics=['binary_accuracy'])

# %%
rede_neural.fit(x_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9061 - loss: 0.3585
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9305 - loss: 0.1828
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.9367 - loss: 0.2123
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9141 - loss: 0.2515
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9305 - loss: 0.2904
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9134 - loss: 0.2666
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9361 - loss: 0.2355
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9278 - loss: 0.2495
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9412 - loss: 0.2048
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9427 - loss: 0.2098
# Epoch 11/100
# ...

# %%
rede_neural.evaluate(x_train, y_train)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.9543 - loss: 0.1428
# [0.19696009159088135, 0.9436619877815247]

# %%
pesos0 = rede_neural.layers[0].get_weights()
pesos0
# Out:
# [array([[-2.03147084e-01, -2.23144749e-03, -5.83292544e-02,
#           1.58742249e-01,  7.55265802e-02,  8.45021605e-02,
#          -6.56308532e-02, -4.41960879e-02, -4.63372357e-02,
#           1.33348280e-03, -1.51380658e-01, -3.02822236e-02,
#          -2.42441529e-04,  1.50610298e-01, -5.95884956e-03,
#           6.16312921e-02],
#         [-1.67479232e-01,  8.92102793e-02, -3.50593068e-02,
#           3.13881814e-01, -1.69503980e-03, -2.21110620e-02,
#          -2.29904249e-01, -2.40644380e-01, -3.03746592e-02,
#           3.69249769e-02, -2.57554501e-01, -2.16701534e-02,
#           6.64708465e-02,  1.15002781e-01,  1.68110635e-02,
#           3.87315750e-01],
#         [-1.37709424e-01,  6.43456578e-02,  2.27729175e-02,
#           5.85920177e-02, -6.80816397e-02,  4.77206595e-02,
#          -1.33431748e-01,  3.37181315e-02,  1.56570189e-02,
#          -4.82480340e-02,  6.80801496e-02,  1.16040017e-02,
#           2.77692042e-02, -1.70746893e-01,  1.26012236e-01,
# ...

# %%
len(pesos0)
# Out:
# 2

# %%
pesos0[1]
# Out:
# array([-0.10242868,  0.20246221, -0.05354344, -0.09282228,  0.03148331,
#         0.08094171, -0.00663514,  0.06010672,  0.        , -0.18736906,
#         0.16514905, -0.10793611,  0.07909292, -0.12144715,  0.32629967,
#         0.00840984], dtype=float32)

# %%
len(pesos0[1])
# Out:
# 16
