# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click !here goes the icon of the corresponding button in the gutter! button.
# To debug a cell, press Alt+Shift+Enter, or click !here goes the icon of the corresponding button in the gutter! button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/jupyter-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import pandas as pd

# %%
import pandas as pd

# Caminho para o arquivo
arquivo = 'dados combustivel/ca-2019-01.csv'

# Leitura do CSV com ajustes necessários
dados = pd.read_csv(
    arquivo,
    delimiter=';',       # Define o separador como ponto e vírgula
    encoding='latin-1',  # Codificação mais comum para dados brasileiros
    low_memory=False,    # Evita dividir a leitura em chunks
    na_values=['', ' '], # Trata células vazias como NaN
    dtype=str            # Garante que todas as colunas sejam lidas como texto inicialmente
)

# Exibir as primeiras linhas para verificar
dados.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla  Municipio  \
# 0                SE             SP  GUARULHOS
# 1                SE             SP  GUARULHOS
# 2                SE             SP  GUARULHOS
# 3                SE             SP  GUARULHOS
# 4                 S             RS     CANOAS
#
#                                        Revenda      CNPJ da Revenda  \
# 0                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
#
#                 Nome da Rua Numero Rua          Complemento      Bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# ...

# %%
dados201901 = pd.read_csv('dados combustivel/ca-2019-01.csv', delimiter=';')
dados201901.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP  GUARULHOS
# 1             SE             SP  GUARULHOS
# 2             SE             SP  GUARULHOS
# 3             SE             SP  GUARULHOS
# 4              S             RS     CANOAS
#
#                                        Revenda      CNPJ da Revenda  \
# 0                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
#
#                 Nome da Rua Numero Rua          Complemento      Bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 2  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# ...

# %%
dados201902 = pd.read_csv('dados combustivel/ca-2019-02.csv', delimiter=';', encoding='latin-1')
dados201901.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla  Municipio  \
# 0                SE             SP  GUARULHOS
# 1                SE             SP  GUARULHOS
# 2                SE             SP  GUARULHOS
# 3                SE             SP  GUARULHOS
# 4                 S             RS     CANOAS
#
#                                        Revenda      CNPJ da Revenda  \
# 0                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
#
#                 Nome da Rua Numero Rua          Complemento      Bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# ...

# %%
dados20201 = pd.read_csv('dados combustivel/ca-2020-01.csv', delimiter=';', encoding='latin-1')
dados20201.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla  Municipio                       Revenda  \
# 0                SE             SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA
# 1                SE             SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA
# 2                SE             SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA
# 3                SE             SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA
# 4                NE             BA   SALVADOR  PETROBRAS DISTRIBUIDORA S.A.
#
#        CNPJ da Revenda               Nome da Rua Numero Rua  \
# 0   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 1   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 2   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 3   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 4   34.274.233/0015-08         RUA EDISTIO PONDE        474
#
#            Complemento      Bairro        Cep     Produto Data da Coleta  \
# ...

# %%
dados20202 = pd.read_csv('dados combustivel/ca-2020-02.csv', delimiter=';', dtype={'Valor de Compra': str})

# %%
dados20202 = pd.read_csv('dados combustivel/ca-2020-02.csv', delimiter=';', low_memory=False)
dados20202.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             SP  SOROCABA
# 1             SE             SP  SOROCABA
# 2             SE             SP  SOROCABA
# 3             NE             BA  SALVADOR
# 4             NE             BA  SALVADOR
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3                       PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 4                       PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
dados20211 = pd.read_csv('dados combustivel/ca-2021-01.csv', delimiter=';', encoding='latin-1')
dados20211.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla     Municipio  \
# 0                 S             RS  SAO LEOPOLDO
# 1                 S             RS  SAO LEOPOLDO
# 2                 S             RS  SAO LEOPOLDO
# 3                 S             RS  SAO LEOPOLDO
# 4                 S             RS  SAO LEOPOLDO
#
#                                  Revenda      CNPJ da Revenda  \
# 0  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 1  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 2  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 3  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 4  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
#
#         Nome da Rua Numero Rua Complemento    Bairro        Cep  \
# 0  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# 1  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# 2  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# ...

# %%
dados20212 = pd.read_csv('dados combustivel/ca-2021-02.csv', delimiter=';', encoding='latin-1')
dados20212.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             NE             CE  MARACANAU
# 1             NE             CE  MARACANAU
# 2             NE             CE  MARACANAU
# 3             NE             CE  MARACANAU
# 4             NE             CE  MARACANAU
#
#                                         Revenda      CNPJ da Revenda  \
# 0  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 1  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 2  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 3  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 4                     LUIZA GLAURIA R T MENEZES   03.602.329/0001-10
#
#                               Nome da Rua Numero Rua Complemento  \
# 0  RODOVIA MARANGUAPE - FORTALEZA - KM 06        S/N         NaN
# 1  RODOVIA MARANGUAPE - FORTALEZA - KM 06        S/N         NaN
# 2  RODOVIA MARANGUAPE - FORTALEZA - KM 06        S/N         NaN
# ...

# %%
dados20221 = pd.read_csv('dados combustivel/ca-2021-01.csv', delimiter=';', encoding='latin-1')
dados20221.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla     Municipio  \
# 0                 S             RS  SAO LEOPOLDO
# 1                 S             RS  SAO LEOPOLDO
# 2                 S             RS  SAO LEOPOLDO
# 3                 S             RS  SAO LEOPOLDO
# 4                 S             RS  SAO LEOPOLDO
#
#                                  Revenda      CNPJ da Revenda  \
# 0  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 1  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 2  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 3  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 4  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
#
#         Nome da Rua Numero Rua Complemento    Bairro        Cep  \
# 0  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# 1  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# 2  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# ...

# %%
dados20221 = pd.read_csv('dados combustivel/ca-2021-01.csv', delimiter=';', encoding='latin-1')
dados20221.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla     Municipio  \
# 0                 S             RS  SAO LEOPOLDO
# 1                 S             RS  SAO LEOPOLDO
# 2                 S             RS  SAO LEOPOLDO
# 3                 S             RS  SAO LEOPOLDO
# 4                 S             RS  SAO LEOPOLDO
#
#                                  Revenda      CNPJ da Revenda  \
# 0  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 1  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 2  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 3  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 4  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
#
#         Nome da Rua Numero Rua Complemento    Bairro        Cep  \
# 0  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# 1  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# 2  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# ...

# %%
dados20222 = pd.read_csv('dados combustivel/ca-2021-02.csv', delimiter=';', encoding='latin-1')
dados20222.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             NE             CE  MARACANAU
# 1             NE             CE  MARACANAU
# 2             NE             CE  MARACANAU
# 3             NE             CE  MARACANAU
# 4             NE             CE  MARACANAU
#
#                                         Revenda      CNPJ da Revenda  \
# 0  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 1  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 2  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 3  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 4                     LUIZA GLAURIA R T MENEZES   03.602.329/0001-10
#
#                               Nome da Rua Numero Rua Complemento  \
# 0  RODOVIA MARANGUAPE - FORTALEZA - KM 06        S/N         NaN
# 1  RODOVIA MARANGUAPE - FORTALEZA - KM 06        S/N         NaN
# 2  RODOVIA MARANGUAPE - FORTALEZA - KM 06        S/N         NaN
# ...

# %%
dados20231 = pd.read_csv('dados combustivel/ca-2023-01.csv', delimiter=';', encoding='latin-1')
dados20231.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla  Municipio  \
# 0                SE             SP   SOROCABA
# 1                SE             SP   SOROCABA
# 2                SE             SP   SOROCABA
# 3                NE             AL  ARAPIRACA
# 4                NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 4  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
dados20232 = pd.read_csv('dados combustivel/ca-2023-02.csv', delimiter=';', encoding='latin-1')
dados20232.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla        Municipio  \
# 0                SE             SP         SOROCABA
# 1                SE             SP         SOROCABA
# 2                SE             SP         SOROCABA
# 3                 N             AC  CRUZEIRO DO SUL
# 4                 N             AC  CRUZEIRO DO SUL
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3                           CARDINAL E OLIVEIRA LTDA   03.608.766/0006-56
# 4                           CARDINAL E OLIVEIRA LTDA   03.608.766/0006-56
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
dados20241 = pd.read_csv('dados combustivel/ca-2024-01.csv', delimiter=';', encoding='latin-1')
dados20241.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla  Municipio  \
# 0                NE             AL  ARAPIRACA
# 1                NE             AL  ARAPIRACA
# 2                NE             AL  ARAPIRACA
# 3                NE             AL  ARAPIRACA
# 4                NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 1  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 2  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 3  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 4                      AUTO POSTO SAO FRANCISCO LTDA   12.706.529/0001-04
#
#          Nome da Rua Numero Rua Complemento           Bairro        Cep  \
# 0     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 1     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# ...

# %%
dados20241 = pd.read_csv('dados combustivel/ca-2024-01.csv', delimiter=';', header=0, encoding='latin-1', skipinitialspace=True)
dados20241.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla  Municipio  \
# 0                NE             AL  ARAPIRACA
# 1                NE             AL  ARAPIRACA
# 2                NE             AL  ARAPIRACA
# 3                NE             AL  ARAPIRACA
# 4                NE             AL  ARAPIRACA
#
#                                              Revenda     CNPJ da Revenda  \
# 0  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...  02.817.655/0001-82
# 1  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...  02.817.655/0001-82
# 2  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...  02.817.655/0001-82
# 3  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...  02.817.655/0001-82
# 4                      AUTO POSTO SAO FRANCISCO LTDA  12.706.529/0001-04
#
#          Nome da Rua Numero Rua Complemento           Bairro        Cep  \
# 0     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 1     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# ...

# %%
# Carregar as 10 primeiras linhas para inspecionar
dados20241 = pd.read_csv('dados combustivel/ca-2024-01.csv', delimiter=';', encoding='latin-1', nrows=10)
dados20241.head(100)
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla  Municipio  \
# 0                NE             AL  ARAPIRACA
# 1                NE             AL  ARAPIRACA
# 2                NE             AL  ARAPIRACA
# 3                NE             AL  ARAPIRACA
# 4                NE             AL  ARAPIRACA
# 5                NE             AL  ARAPIRACA
# 6                NE             AL  ARAPIRACA
# 7                NE             AL  ARAPIRACA
# 8                NE             AL  ARAPIRACA
# 9                NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 1  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 2  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 3  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 4                      AUTO POSTO SAO FRANCISCO LTDA   12.706.529/0001-04
# ...
